# %%
import matplotlib.pyplot as plt
x1 = [5,7,8,9,10]
y1 = [12,5,10,12,13]


x2 = [8,9,10,11,12,13]
y2 = [5,3,2,1,8,9]

plt.plot(x1,y1)
plt.plot(x2,y2)

# %%
plt.plot(x1,y1,c='g')
plt.plot(x2,y2,c='b')

# %%
plt.plot(x1,y1,c='g',label='Line 1')
plt.plot(x2,y2,c='b',label='Line 2')
plt.legend()

# %%
plt.plot(x1,y1,c='g',label='Line 1')
plt.plot(x2,y2,c='b',label='Line 2')
plt.xlim(.5,20)#limit to x axis
plt.ylim(.1,20)#limit to y axis
plt.legend()

# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\Boon\OneDrive\Python DSA\Dataset\medals_by_country_2016.csv')

# %%
print(data.head())
# Out:
#       Unnamed: 0  Bronze  Gold  Silver
# 0  United States      67   137      52
# 1        Germany      67    47      43
# 2  Great Britain      26    64      55
# 3         Russia      35    50      28
# 4          China      35    44      30

# %%
data.shape
# Out:
# (10, 4)

# %%
data=data.rename(columns={'Unnamed: 0':'Country'})

# %%
data.head()
# Out:
#          Country  Bronze  Gold  Silver
# 0  United States      67   137      52
# 1        Germany      67    47      43
# 2  Great Britain      26    64      55
# 3         Russia      35    50      28
# 4          China      35    44      30

# %%
plt.bar(data['Country'],data['Gold'])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(data['Country'],data['Gold'])
plt.xticks(rotation=30)
plt.show()

# %%
plt.bar(data['Country'],data['Gold'])
plt.title('Countries with gold medals')
plt.xticks(rotation=30)
plt.show()

# %%
plt.bar(data['Country'],data['Gold'])
plt.title('Countries with gold medals')
plt.xticks(rotation=30)
plt.xlabel('Country')
plt.ylabel('Gold')
plt.show()

# %%
plt.bar(data['Country'],data['Gold'],color='c')
plt.title('Countries with gold medals')
plt.xticks(rotation=30)
plt.xlabel('Country')
plt.ylabel('Gold')
plt.show()

# %%
##Using Pandas for Visualization

data['Gold'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
data=data.set_index('Country')

# %%
data.head()
# Out:
#                Bronze  Gold  Silver
# Country
# United States      67   137      52
# Germany            67    47      43
# Great Britain      26    64      55
# Russia             35    50      28
# China              35    44      30

# %%
data['Gold'].plot.bar()
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
data['Gold'].sort_values()
# Out:
# Country
# Canada             4
# Italy              8
# Japan             17
# France            20
# Australia         23
# China             44
# Germany           47
# Russia            50
# Great Britain     64
# United States    137
# Name: Gold, dtype: int64

# %%
data['Gold'].sort_values().plot.bar()
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
data['Gold'].sort_values(ascending=True).plot.bar()
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
data[['Gold','Silver','Bronze']].plot.bar()
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
##Box Plot
plt.boxplot(data['Silver'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x224b4183c10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x224b41941f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x224b4183910>],
#  'medians': [<matplotlib.lines.Line2D at 0x224b4194790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x224b4194a60>],
#  'means': []}

# %%
plt.boxplot(data['Gold'])
plt.show()

# %%
plt.boxplot(data)
plt.show()

# %%
##Pie Chart

countries=['India','USA','UK','UAE']
population=[123,20,30,40]

# %%
plt.pie(population,labels=countries)
plt.show()

# %%
plt.pie(population,labels=countries,autopct="%1.lf%%")
plt.show()

# %%
##Histogram
data2=pd.read_csv(r'C:\Users\Boon\OneDrive\Python DSA\Dataset\auto-mpg.csv')

# %%
data2.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
data2.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
plt.hist(data2['mpg'])
plt.show()

# %%
plt.hist(data2['mpg'])
plt.title('Distribution of mpg')
plt.show()

# %%
plt.hist(data2['mpg'])
plt.title('Distribution of mpg')
plt.figure(figsize=(5,10))
plt.show()

# %%
plt.hist(data2['mpg'])
plt.title('Distribution of mpg',fontsize=20)
plt.figure(figsize=(150,10))
plt.show()

# %%
plt.hist(data2['mpg'],color='#FF4034')
plt.title('Distribution of mpg',fontsize=20)
plt.figure(figsize=(150,10))
plt.show()

# %%
plt.hist(data2['mpg'],color='#FF4034',rwidth=.98)
plt.title('Distribution of mpg',fontsize=20)
plt.figure(figsize=(150,10))
plt.show()

# %%
plt.hist(data2['mpg'],color='#FF9994',rwidth=.98,cumulative=True)
plt.title('Distribution of mpg',fontsize=20)
plt.figure(figsize=(150,10))
plt.show()

# %%
data2.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
data2.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
data2['horsepower']=data2['horsepower'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9536\112987642.py in <module>
# ----> 1 data2['horsepower']=data2['horsepower'].astype(float)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
# ...

# %%
data2[data2['horsepower']=='?'].index
# Out:
# Int64Index([32, 126, 330, 336, 354, 374], dtype='int64')

# %%
data2=data2.drop([32, 126, 330, 336, 354, 374])

# %%
data2.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
data2['horsepower']=data2['horsepower'].astype(float)

# %%
data2.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
data2.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
plt.hist(data2['horsepower'],color='#369991',rwidth=.98)
plt.show()

# %%
data2['mpg'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
##Scatterplots

plt.scatter(data2['horsepower'],data2['mpg'])
plt.show()

# %%
plt.scatter(data2['horsepower'],data2['mpg'],s=1)
plt.show()

# %%
plt.scatter(data2['horsepower'],data2['mpg'],s=10,marker='x',color='#9292d1')
plt.show()

# %%
import seaborn as sns

##pair Plot
sns.pairplot(data2)

# %%
data_col=data2[['mpg','displacement','horsepower','weight']]
sns.heatmap(data_col.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
##boxplot
sns.boxplot(x='origin',y='mpg',data=data2)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>
